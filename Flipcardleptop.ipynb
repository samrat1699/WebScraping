# %% [markdown]
# ## Library

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# ## get weblink

# %%
web = requests.get('https://www.flipkart.com/laptops/pr?sid=6bo%2Cb5g&otracker=categorytree&fm=neo%2Fmerchandising&iid=M_efec9092-04ab-44b4-8b4a-e427bf1f9f6e_1_372UD5BXDFYS_MC.34WHNYFH5V2Y&otracker=hp_rich_navigation_8_1.navigationCard.RICH_NAVIGATION_Electronics%7ELaptop%2Band%2BDesktop_34WHNYFH5V2Y&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_8_L1_view-all&cid=34WHNYFH5V2Y&page=1').text
soup=BeautifulSoup(web, 'html.parser')
#print(soup.prettify())

# %%
for i in soup.find_all('h2'):
    print(i.text.strip())
# Out:
# Laptops Price List
# Buy Branded Laptops Online
# Laptop Price List in India 2022
# Check out new launch: Nokia Pure Book
# Question and Answers

# %%
for i in soup.find_all('p'):
    print(i.text.strip())
# Out:
# Whether a college-going student or an entrepreneur, you need a laptop to conduct your day-to-day work. The latest Dell i5 laptops offer a perfect solution giving you the best of both worlds. When it comes to purchasing an i5 laptop, there are several options available on the website. However, selecting the correct laptop is important, and you need to know your requirements before you pick the right one. The Dell i5 laptop not only looks stylish but also exhibits a powerhouse performance. The powerful processor, along with the Windows 10 Home operating system, allows you to accomplish routine tasks and also enjoy gaming. These laptops come with a large storage capacity and efficient RAM  (DDR4, DDR3 or LPDDR4X) allowing you to store a large amount of critical data and operate without lags. The processor speed guarantees that your productivity is at an optimal level. You can browse various i5 laptops like gaming laptops, thin and light laptops, notebooks, or 2-in-1 laptops as per your 
# ...

# %%
product = soup.find_all('div', class_='_3pLy-c row')
for i in product:
    print(i.find('div', class_='_4rR01T').text.strip())
# Out:
# DELL Core i5 11th Gen - (16 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce RTX 3050) G15-5...
# Lenovo IdeaPad Flex 3 Chromebook Celeron Dual Core - (4 GB/128 GB EMMC Storage/Chrome OS) CB 11IJL6 Ch...
# RedmiBook Pro Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) Thin and Light Laptop
# ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515JA-EJ362WS | X515JA-E...
# acer Aspire 7 Ryzen 5 Hexa Core AMD R5-5500U - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA G...
# APPLE 2020 Macbook Air M1 - (8 GB/256 GB SSD/Mac OS Big Sur) MGN63HN/A
# HP Pavilion Ryzen 5 Hexa Core AMD R5-5600H - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeF...
# Lenovo IdeaPad 3 Chromebook Celeron Dual Core - (4 GB/64 GB EMMC Storage/Chrome OS) ideapad 3 cb 11igl...
# realme Book (Slim) Core i3 11th Gen - (8 GB/256 GB SSD/Windows 10 Home) RMNB1001 Thin and Light Laptop
# ...

# %%
product = soup.find_all('div', class_='_3pLy-c row')
for i in product:
    print(i.find('div', class_='_3LWZlK').text.strip())
# Out:
# 4.1
# 3.6
# 4.2
# 4.3
# 4.5
# 4.7
# 4.5
# 3.5
# 4.4
# 4.3
# 4.1
# 4.2
# 4.4
# 4.2
# 4.1
# 4.3
# 4.3
# 3.9
# 4.2
# 4.1
# 2.8
# 4.3
# 4.3
# 4.2

# %%
product = soup.find_all('div', class_='_3pLy-c row')
for i in product:
    print(i.find('span', class_='_2_R_DZ').text.strip())
# Out:
# 84 Ratings & 4 Reviews
# 145 Ratings & 22 Reviews
# 3,065 Ratings & 346 Reviews
# 7,593 Ratings & 762 Reviews
# 4,673 Ratings & 593 Reviews
# 8,126 Ratings & 740 Reviews
# 90 Ratings & 10 Reviews
# 1,225 Ratings & 145 Reviews
# 11,541 Ratings & 1,724 Reviews
# 225 Ratings & 22 Reviews
# 25 Ratings & 4 Reviews
# 3,469 Ratings & 332 Reviews
# 1,559 Ratings & 199 Reviews
# 1,472 Ratings & 126 Reviews
# 937 Ratings & 89 Reviews
# 2,757 Ratings & 239 Reviews
# 585 Ratings & 48 Reviews
# 78 Ratings & 8 Reviews
# 824 Ratings & 64 Reviews
# 198 Ratings & 19 Reviews
# 90 Ratings & 18 Reviews
# 150 Ratings & 14 Reviews
# 5,152 Ratings & 452 Reviews
# 318 Ratings & 34 Reviews

# %%
price = soup.find_all('div', class_='col col-5-12 nlI3QM')
for i in price:
    print(i.find('div', class_='_30jeq3 _1_WHN1').text.strip())
# Out:
# ₹72,490
# ₹28,490
# ₹27,990
# ₹32,990
# ₹47,990
# ₹87,990
# ₹62,990
# ₹18,490
# ₹36,999
# ₹49,990
# ₹72,547
# ₹38,799
# ₹47,990
# ₹57,890
# ₹61,999
# ₹42,990
# ₹37,228
# ₹69,990
# ₹31,021
# ₹28,129
# ₹21,800
# ₹38,990
# ₹42,990
# ₹29,990

# %%
price = soup.find_all('div', class_='col col-5-12 nlI3QM')
for i in price:
    print(i.find('div', class_='_3I9_wc _27UcVY').text.strip())
# Out:
# ₹95,999
# ₹40,490
# ₹51,999
# ₹45,990
# ₹89,999
# ₹99,900
# ₹81,869
# ₹24,840
# ₹54,999
# ₹64,990
# ₹92,549
# ₹59,390
# ₹72,990
# ₹67,832
# ₹72,331
# ₹49,508
# ₹60,890
# ₹1,21,608
# ₹46,263
# ₹40,490
# ₹34,890
# ₹51,544
# ₹57,990
# ₹39,288

# %%
descriptions = [] # Create a list to store the descriptions
processors=[]
ram=[]
os=[]
storage=[]
inches=[]
warranty=[]
prices = []

ratings = []

# %%
pages = list(range(1,41))
for page in pages:
  web = requests.get('https://www.flipkart.com/laptops/pr?sid=6bo%2Cb5g&otracker=categorytree&fm=neo%2Fmerchandising&iid=M_efec9092-04ab-44b4-8b4a-e427bf1f9f6e_1_372UD5BXDFYS_MC.34WHNYFH5V2Y&otracker=hp_rich_navigation_8_1.navigationCard.RICH_NAVIGATION_Electronics%7ELaptop%2Band%2BDesktop_34WHNYFH5V2Y&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_8_L1_view-all&cid=34WHNYFH5V2Y&page={}'.format(page)).text
  soup=BeautifulSoup(web, 'html.parser')  # URL of the website which you want to scrape
  #content = req.content # Get the content
  
  #print(soup.prettify())

  desc = soup.find_all('div' , class_='_4rR01T')
  for i in range(len(desc)):
      descriptions.append(desc[i].text)
  len(descriptions)

  commonclass = soup.find_all('li',class_='rgWa7D') # We observe that the classnames for the different specifications are under one div.So we need to apply some method to extract the different features.
  # Create empty lists for the features
  for i in range(0,len(commonclass)):
    p=commonclass[i].text # Extracting the text from the tags
    if("Core" in p): 
        processors.append(p)
    elif("RAM" in p): 
        ram.append(p)
    elif("HDD" in p or "SSD" in p):
        storage.append(p)
    elif("Operating" in p):
        os.append(p)
    elif("Display" in p):
        inches.append(p)
    elif("Warranty" in p):
        warranty.append(p)

  price = soup.find_all('div',class_='_30jeq3 _1_WHN1') 
  # Extracting price of each laptop from the website
  for i in range(len(price)):
    prices.append(price[i].text)
    len(prices)
    
  

  rating = soup.find_all('div',class_='_3LWZlK') 
  #Extracting the ratings of each laptop from the website
  for i in range(len(rating)):
    ratings.append(rating[i].text)
    len(ratings)

# %%
print(len(descriptions))
print(len(processors))
print(len(ram))
print(len(os))
print(len(storage))
print(len(warranty))
print(len(inches))
print(len(prices))

print(len(ratings))
# Out:
# 1920
# 1966
# 2329
# 1929
# 1908
# 1507
# 2427
# 1920
# 2793

# %%
dataset
# Out:
#                                             Description  \
# 0     Lenovo ThinkBook 13s Core i5 11th Gen - (8 GB/...
# 1     Lenovo ThinkBook 13s Core i5 11th Gen - (8 GB/...
# 2     Lenovo ThinkBook 13s Core i5 11th Gen - (8 GB/...
# 3     Lenovo ThinkBook 13s Core i5 11th Gen - (8 GB/...
# 4     Lenovo ThinkBook 13s Core i5 11th Gen - (8 GB/...
# ...                                                 ...
# 1242  Lenovo ThinkBook 13s Core i5 11th Gen - (8 GB/...
# 1243  Lenovo ThinkBook 13s Core i5 11th Gen - (8 GB/...
# 1244  Lenovo ThinkBook 13s Core i5 11th Gen - (8 GB/...
# 1245  Lenovo ThinkBook 13s Core i5 11th Gen - (8 GB/...
# 1246  Lenovo ThinkBook 13s Core i5 11th Gen - (8 GB/...
#
#                                               Processor             RAM  \
# 0     Processor: Intel i3-1215U (0.9 GHz up to 4.40 ...  16 GB DDR4 RAM
# 1     Processor: Intel i3-1215U (0.9 GHz up to 4.40 ...  16 GB DDR4 RAM
# 2     Processor: Intel i3-1215U (0.9 GHz up to 4.40 ...  16 GB DDR4 RAM
# ...

# %%
dataset.to_csv('laptops22.csv')
